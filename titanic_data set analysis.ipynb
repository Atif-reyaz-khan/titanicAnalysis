# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
import pandas as pd
plt.rcParams['figure.figsize']=(20.,10.)

# %%
titanic_data=pd.read_csv('train.csv')

# %%
titanic_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
print("total number of passenger traveling",len(titanic_data))
# Out:
# total number of passenger traveling 891

# %%
## Analysing data

# %%
 sns.countplot(x='Survived',data=titanic_data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
 sns.countplot(x='Survived',hue='Sex',data=titanic_data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
 sns.countplot(x='Survived',hue='Pclass',data=titanic_data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
titanic_data['Age'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.countplot(x='Pclass',data=titanic_data)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
titanic_data["Fare"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot(x='SibSp',data=titanic_data)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %% [markdown]
# #Data wangling

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(titanic_data.isnull(),yticklabels=False ,cmap="viridis" )
# Out:
# <AxesSubplot:>

# %%
 sns.boxplot(x="Pclass",y="Age",data=titanic_data)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
titanic_data.drop("Cabin",axis=1,inplace=True)

# %%
titanic_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
titanic_data.dropna(inplace=True)

# %%
sns.heatmap(titanic_data.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
sex=pd.get_dummies(titanic_data['Sex'],drop_first=True)

# %%
sex.head(5)
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
Embarked=pd.get_dummies(titanic_data['Embarked'])

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 885      5            382652  29.1250        Q
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [712 rows x 11 columns]

# %%
Embarked
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 885  0  1  0
# 886  0  0  1
# 887  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [712 rows x 3 columns]

# %%
sex
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 885     0
# 886     1
# 887     0
# 889     1
# 890     1
#
# [712 rows x 1 columns]

# %%
pcl=pd.get_dummies(titanic_data['Pclass'])

# %%
pcl
# Out:
#      1  2  3
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    1  0  0
# 4    0  0  1
# ..  .. .. ..
# 885  0  0  1
# 886  0  1  0
# 887  1  0  0
# 889  1  0  0
# 890  0  0  1
#
# [712 rows x 3 columns]

# %%
titanic_data=pd.concat([titanic_data,sex,Embarked,pcl],axis=1)

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked  male  C  Q  S  1  2  3
# 0        0         A/5 21171   7.2500        S     1  0  0  1  0  0  1
# 1        0          PC 17599  71.2833        C     0  1  0  0  1  0  0
# 2        0  STON/O2. 3101282   7.9250        S     0  0  0  1  0  0  1
# 3        0            113803  53.1000        S     0  0  0  1  1  0  0
# 4        0            373450   8.0500        S     1  0  0  1  0  0  1
# ..     ...               ...      ...      ...   ... .. .. .. .. .. ..
# 885      5            382652  29.1250        Q     0  0  1  0  0  0  1
# 886      0            211536  13.0000        S     1  0  0  1  0  1  0
# 887      0            112053  30.0000        S     0  0  0  1  1  0  0
# 889      0            111369  30.0000        C     1  1  0  0  1  0  0
# 890      0            370376   7.7500        Q     1  0  1  0  0  0  1
#
# [712 rows x 18 columns]

# %%
titanic_data.drop(['Sex','Embarked','PassengerId','Name','Ticket','C'],axis=1,inplace=True)

# %%
titanic_data.head(5)
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S  1  2  3
# 0         0       3  22.0      1      0   7.2500     1  0  1  0  0  1
# 1         1       1  38.0      1      0  71.2833     0  0  0  1  0  0
# 2         1       3  26.0      0      0   7.9250     0  0  1  0  0  1
# 3         1       1  35.0      1      0  53.1000     0  0  1  1  0  0
# 4         0       3  35.0      0      0   8.0500     1  0  1  0  0  1

# %%
titanic_data
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S  1  2  3
# 0           0       3  22.0      1      0   7.2500     1  0  1  0  0  1
# 1           1       1  38.0      1      0  71.2833     0  0  0  1  0  0
# 2           1       3  26.0      0      0   7.9250     0  0  1  0  0  1
# 3           1       1  35.0      1      0  53.1000     0  0  1  1  0  0
# 4           0       3  35.0      0      0   8.0500     1  0  1  0  0  1
# ..        ...     ...   ...    ...    ...      ...   ... .. .. .. .. ..
# 885         0       3  39.0      0      5  29.1250     0  1  0  0  0  1
# 886         0       2  27.0      0      0  13.0000     1  0  1  0  1  0
# 887         1       1  19.0      0      0  30.0000     0  0  1  1  0  0
# 889         1       1  26.0      0      0  30.0000     1  0  0  1  0  0
# 890         0       3  32.0      0      0   7.7500     1  1  0  0  0  1
#
# [712 rows x 12 columns]

# %% [markdown]
# # Train Data

# %%
x=titanic_data.drop('Survived',axis=1)
y=titanic_data['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=1)

# %%
X_train
# Out:
#      Pclass   Age  SibSp  Parch      Fare  male  Q  S  1  2  3
# 407       2   3.0      1      1   18.7500     1  0  1  0  1  0
# 353       3  25.0      1      0   17.8000     1  0  1  0  0  1
# 827       2   1.0      0      2   37.0042     1  0  0  0  1  0
# 694       1  60.0      0      0   26.5500     1  0  1  1  0  0
# 856       1  45.0      1      1  164.8667     0  0  1  1  0  0
# ..      ...   ...    ...    ...       ...   ... .. .. .. .. ..
# 182       3   9.0      4      2   31.3875     1  0  1  0  0  1
# 809       1  33.0      1      0   53.1000     0  0  1  1  0  0
# 94        3  59.0      0      0    7.2500     1  0  1  0  0  1
# 292       2  36.0      0      0   12.8750     1  0  0  0  1  0
# 51        3  21.0      0      0    7.8000     1  0  1  0  0  1
#
# [356 rows x 11 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression(solver='lbfgs',class_weight='balanced', max_iter=10000)

# %%
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=10000)

# %%
predictions=logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.77      0.81       218
#            1       0.68      0.80      0.74       138
#
#     accuracy                           0.78       356
#    macro avg       0.77      0.78      0.77       356
# weighted avg       0.79      0.78      0.78       356

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,predictions)
# Out:
# array([[167,  51],
#        [ 28, 110]])

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,predictions));
# Out:
# 0.7780898876404494
